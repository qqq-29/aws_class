# %%
# 키 데이터와 신발 데이터를 이용하여 학습하고, 키 데이터를 이용하여 신발 사이즈를 예측하는 예제
# 고수준으로 작성 => keras 모델이용
import tensorflow as tf
키데이터 = tf.constant([170, 180, 175, 160], dtype=tf.float32)
신발데이터 = tf.constant([260, 270, 265, 255], dtype=tf.float32)

# %%
# 모델설계
model = tf.keras.Sequential([
	# 레이어를 작성
	# 마지막 레이어는 출력층
	# 1은 해당 레이어를 지나면 결과가 몇개 나와야 하는지를 결정
	# 지금은 신발사이즈 값 1개만 나오면 되니까 1
	# input_shape(1,) : 입력층의 형태, 입력층은 키 1개이니까 1,
	tf.keras.layers.Dense(1, input_shape=(1,))
])

# 모델 설정. 옵티마이저를 어떤 모델로 할건지, 오차는 어떤 방식으로 계산할건지를 설정
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1), loss='mse')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\C603\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 학습 실행
model.fit(키데이터, 신발데이터, epochs=1000, verbose=0)

# %%
import numpy as np
측정키 = 173
# 텐서 모델들은 예측할 때, numpy 리스트가 필요
예측신발 = model.predict(np.array([[측정키]], dtype='float32'))
예측신발
print(f'측정키 : {측정키}, 에측신발사이즈 : {예측신발[0][0]:.2f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 측정키 : 173, 에측신발사이즈 : 264.91

# %%
# 단계,명령어,실제의미,비유 
# 1단계,.compile(),학습 방식 설정,"""어떤 과목을 어떤 방식으로 공부할지 계획 짜기"""
# 2단계,.fit(),실제 학습,"""문제집(데이터)을 수백 번 반복해서 풀어보기"""
# 3단계,.predict(),예측하기,"""배운 내용을 바탕으로 새로운 문제의 답을 맞혀보기"""
# 보너스,.evaluate(),모델 평가,"""모의고사를 봐서 내가 얼마나 똑똑해졌나 채점하기"""
