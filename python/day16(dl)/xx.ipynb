# %%
# A = w1x1 + w2x2
# B = w3x2 + w4x2
# Y = w5A + w6B
# Y = w5*(w1x1 + w2x2) + w6(w3x1 + w4x2)
#   = w1w5x1 + w2w5x2 +
#			w3w6x1 + w4x6x2
#		= (w1w5  +  w3w6)x1 +
# 		(w2w5  +  w4w6)x2
# 	= w7x1  +  w8x2

# 딥러닝
# - 입력층
# - 은닉층
# - 출력층
# 활성화함수
# - 비선형이 되지 않게 하는 함수
# - 다음 신경망에 보낼지 말지를 결정하는 함수
# 순전파 => 학습
# 역전파 => 가중치 변경하는 과정으로. 순전파의 역순 손실함수
# - 실제값와 예측값의 차이인 오차를 계산하는 함수
