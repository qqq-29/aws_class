# %%
import requests
from bs4 import BeautifulSoup

url = "https://apis.data.go.kr/1741000/StanReginCd/getStanReginCdList"
params = {
	'ServiceKey' : '서비스키',
	'pageNo' : 1,
  'numOfRows' : 10,
  'type' : 'xml',
  'locatadd_nm' : '서울특별시'
}

try:
	respsonse = requests.get(url, params=params)
	respsonse.raise_for_status()
	soup = BeautifulSoup(respsonse.text, "lxml-xml")

	# 총 개수
	total_count = soup.find("totalCount").text
	print(f"서울특별시 전체 법정동 수{total_count}")
	# 실제 가져온 데이터들
	rows = soup.find_all("row")
	data = []
	for row in rows:
		region_cd = row.find("region_cd").text # 지역코드
		sido_cd = row.find("sido_cd").text # 시도코드
		locatadd_nm = row.find("locatadd_nm").text # 지역주소명
		locallow_nm = row.find("locallow_nm").text # 최하위 지역명
		data.append({
			'region_cd' : region_cd, 
			'sido_cd' : sido_cd, 
			'locatadd_nm' : locatadd_nm, 
			'locallow_nm' : locallow_nm
		})
	print(data)
	for d in data:
		print(d.get('locatadd_nm'))

except Exception as e:
	print(f"예외발생 : {e}")
# Out:
# 서울특별시 전체 법정동 수493
# [{'region_cd': '1171000000', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구', 'locallow_nm': '송파구'}, {'region_cd': '1171010100', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 잠실동', 'locallow_nm': '잠실동'}, {'region_cd': '1171010200', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 신천동', 'locallow_nm': '신천동'}, {'region_cd': '1171010300', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 풍납동', 'locallow_nm': '풍납동'}, {'region_cd': '1171010400', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 송파동', 'locallow_nm': '송파동'}, {'region_cd': '1171010500', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 석촌동', 'locallow_nm': '석촌동'}, {'region_cd': '1171010600', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 삼전동', 'locallow_nm': '삼전동'}, {'region_cd': '1171010700', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 가락동', 'locallow_nm': '가락동'}, {'region_cd': '1171010800', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 문정동', 'locallow_nm': '문정동'}, {'region_cd': '1171010900', 'sido_cd': '11', 'locatadd_nm': '서울특별시 송파구 장지동', 'locallow_nm': '장지동'}]
# 서울특별시 송파구
# 서울특별시 송파구 잠실동
# 서울특별시 송파구 신천동
# 서울특별시 송파구 풍납동
# 서울특별시 송파구 송파동
# 서울특별시 송파구 석촌동
# 서울특별시 송파구 삼전동
# 서울특별시 송파구 가락동
# 서울특별시 송파구 문정동
# 서울특별시 송파구 장지동

# %%
# 서울특별시 전체 법정동 정보를 가져오는 예제
import requests
from bs4 import BeautifulSoup
import time

def get_stan_regin_list(page : int = 1, num_or_rows : int = 10, locatadd_nm : str = ""):
	"""법정동 정보를 가져와서 리스트로 반환"""

	url = "https://apis.data.go.kr/1741000/StanReginCd/getStanReginCdList"
	params = {
	'ServiceKey' : '서비스키',
	'pageNo' : page,
  'numOfRows' : num_or_rows,
  'type' : 'xml'
}
	if str:
		params['locatadd_nm'] = locatadd_nm
	try:
		respsonse = requests.get(url, params=params)
		respsonse.raise_for_status() #HTTP 오류 확인
		soup = BeautifulSoup(respsonse.text, "lxml-xml")

		# 총 개수
		#total_count = soup.find("totalCount").text
		#print(f"서울특별시 전체 법정동 수{total_count}")
		# 실제 가져온 데이터들
		rows = soup.find_all("row")
		data = []
		for row in rows:
			region_cd = row.find("region_cd").text # 지역코드
			sido_cd = row.find("sido_cd").text # 시도코드
			locatadd_nm = row.find("locatadd_nm").text # 지역주소명
			locallow_nm = row.find("locallow_nm").text # 최하위 지역명
			data.append({
				'region_cd' : region_cd, 
				'sido_cd' : sido_cd, 
				'locatadd_nm' : locatadd_nm, 
				'locallow_nm' : locallow_nm
			})
		return data

	except Exception as e:
		print(f"예외발생 : {e}")
		return []


def get_stan_regin_total_count(locatadd_nm : str = ""):
	"""법정동 전체개수를 조회"""
	url = "https://apis.data.go.kr/1741000/StanReginCd/getStanReginCdList"
	params = {
	'ServiceKey' : '서비스키',
	'pageNo' : 1,
  'numOfRows' : 10,
  'type' : 'xml'
}
	if str:
		params['locatadd_nm'] = locatadd_nm
	try:
		respsonse = requests.get(url, params=params)
		respsonse.raise_for_status()
		soup = BeautifulSoup(respsonse.text, "lxml-xml")

		# 총 개수
		total_count = soup.find("totalCount").text
		print(f"서울특별시 전체 법정동 수{total_count}")

		return int(total_count)

	except Exception as e:
		print(f"예외발생 : {e}")
		return 0
# 시작페이지
page = 1
# 전체개수
total_count = get_stan_regin_total_count()
# 한페이지에 조회할 개수
num_or_rows = 10
# 최대 페이지
max_page = total_count // num_or_rows
# 예로 431개이면 43페이지가 아니라 44페이지어야 함
max_page = max_page if max_page * num_or_rows >= total_count else max_page + 1

# 최종으로 넣을 데이터
data = []

for i in range(1, 10): # 원래는 max인데 10으로 임시 수정 => max로하면 시간 오래 걸림
	tmp = get_stan_regin_list(page=page, num_or_rows=num_or_rows)
	data.extend(tmp)
	print(f"{i}페이지 로딩 완료! ")
	time.sleep(1)

print(len(data))
print(data)
