# %%
# 샘플 데이터를 학습해서 30도일 떄 아이스크림 판매량을 예측하세요
# 그래프도 출력
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 데이터 선정
dataset = pd.read_csv('선형회귀_아이스크림.csv')
print(dataset)
# Out:
#      temperature  sales
# 0           29.2    623
# 1           16.7    340
# 2           32.1    595
# 3           12.6    157
# 4           22.7    488
# ..           ...    ...
# 995         25.1    489
# 996         18.7    406
# 997         19.6    317
# 998         27.9    537
# 999         19.1    343
#
# [1000 rows x 2 columns]

# %%
# 독립변수, 종속변수 분리
X = dataset.iloc[: , :-1]
y = dataset.iloc[: , -1]

# %%
# 훈련,테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
# 학습
sgdr = SGDRegressor(max_iter=1000, eta0=1e-4, random_state=0, verbose=1)
sgdr.fit(X_train, y_train)

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# -- Epoch 1
# Norm: 20.14, NNZs: 1, Bias: 0.732438, T: 800, Avg. loss: 3542.959076
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 20.00, NNZs: 1, Bias: 0.723191, T: 1600, Avg. loss: 1363.822105
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 20.02, NNZs: 1, Bias: 0.719206, T: 2400, Avg. loss: 1362.864503
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 19.88, NNZs: 1, Bias: 0.710418, T: 3200, Avg. loss: 1360.737160
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 19.98, NNZs: 1, Bias: 0.710323, T: 4000, Avg. loss: 1358.919799
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 20.02, NNZs: 1, Bias: 0.708285, T: 4800, Avg. loss: 1360.570252
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 20.07, NNZs: 1, Bias: 0.706458, T: 5600, Avg. loss: 1358.993503
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 19.98, NNZs: 1, Bias: 0.700334, T: 6400, Avg. loss: 1356.869630
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 20.08, NNZs: 1, Bias: 0.700643, T: 7200, Avg. loss: 1357.946312
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 19.95, NNZs: 1, Bias: 0.693277, T: 8000, Avg. loss: 1358.267040
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 19.91, NNZs: 1, Bias: 0.688864, T: 8800, Avg. loss: 1359.128025
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 20.05, NNZs: 1, Bias: 0.690938, T: 9600, Avg. loss: 1357.516862
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 20.18, NNZs: 1, Bias: 0.692336, T: 10400, Avg. loss: 1355.105061
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 20.05, NNZs: 1, Bias: 0.684732, T: 11200, Avg. loss: 1359.797416
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 19.95, NNZs: 1, Bias: 0.678481, T: 12000, Avg. loss: 1356.795279
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 20.01, NNZs: 1, Bias: 0.677736, T: 12800, Avg. loss: 1357.015070
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 19.89, NNZs: 1, Bias: 0.670672, T: 13600, Avg. loss: 1356.578176
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 19.93, NNZs: 1, Bias: 0.669460, T: 14400, Avg. loss: 1358.336749
# Total training time: 0.00 seconds.
# Convergence after 18 epochs took 0.00 seconds
# LinearRegression()

# %%
# 예측
y_predic = sgdr.predict(X_test)

#  341.4909125  646.4364229  740.11249473 528.84305614 377.3668549
#  498.94643748 283.69078307 572.69143019 399.29104192 488.98089792
#  781.96776086 449.1187397  377.3668549  429.18766059 779.97465295
#  313.58740174 259.77348814 692.27790486 698.25722859 203.96646663
#  636.47088335 726.16073935 363.41509952 773.99532921 269.7390277
#  630.49155961 403.27725774 710.21587606 299.63564636 453.10495552
#  783.96086877 413.2427973  628.4984517  524.85684032 602.58804886
#  201.97335872 403.27725774 528.84305614 748.08492637 762.03668175
#  556.7465669  564.71899854 586.64318557 634.47777543 337.50469667
#  644.44331499 327.53915712 544.78791943 331.52537294 299.63564636
#  746.09181846 718.1883077  638.46399126 465.06360299 496.95332957
#  524.85684032 600.59494095 287.6769989  411.24968939 329.53226503
#  646.4364229  682.3123653  441.14630805 744.09871055 241.83551694
#  777.98154504 608.56737259 389.32550236 229.87686947 441.14630805
#  205.95957454 658.39507037 287.6769989  724.16763144 269.7390277
#  698.25722859 469.04981881 305.6149701  740.11249473 339.49780459
#  740.11249473 407.26347356 423.20833685 439.15320014 760.04357384]
# 실제 값 : [839 268 324 613 710 368 298 844 294 367 906 425 425 337 756 606 583 656
#  487 195 200 669 666 271 644 267 406 579 371 308 611 216 259 345 236 489
#  635 753 566 757 294 399 731 523 322 553 228 232 442 302 583 506 605 335
#  201 478 376 312 457 711 379 500 396 454 269 652 280 538 505 715 364 381
#  540 693 472 481 525 690 573 239 276 628 594 675 325 615 782 305 729 639
#  293 362 710 357 605 398 351 707 355 553 624 746 347 669 351 473 462 549
#  340 557 579 688 538 633 394 390 627 682 599 349 547 201 623 301 509 771
#  493 452 401 723 264 235 677 718 276 571 730 294 754 313 692 500 644 275
#  416 701 433 699 524 609 138 454 445 777 716 541 631 666 705 317 564 341
#  475 254 270 776 743 580 453 497 594 630 291 346 341 658 669 470 764 217
#  790 617 386 275 389 184 735 224 697 259 680 551 249 768 278 651 399 489
#  484 744]

# %%
tem_list = [[11], [13], [14]]
for tem in tem_list:
	y_res = lr.predict([tem])
	print(f'{tem}도 판매량:{y_res.round(0)}개')
# 30도일 때 예축된 판매량
y_pred30 = lr.predict([[30]])
print(f'30도 판매량:{y_pred30.round(0)}개')
# Out:
# [11]도 판매량:[218.]개
# [13]도 판매량:[258.]개
# [14]도 판매량:[279.]개
# 30도 판매량:[600.]개
# c:\Users\C603\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\C603\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\C603\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\C603\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# 성능을 확인
print(f'SGD 성능 : {sgdr.score(X_test, y_test)}')
print(f'LR 성능 : {lr.score(X_test, y_test)}')
# Out:
# SGD 성능 : 0.9257294911598377
# LR 성능 : 0.9255130942574286

# %%
# 그랴프로 확인
plt.scatter(X_train, y_train, color='blue') # 훈련 데이터를 점으로 출력
plt.plot(X_train,sgdr.predict(X_train), color='red') # SGDR학슴을 통해 나온 직선
plt.plot(X_test, lr.predict(X_test), color='orange') # LR학습을 통해 나온 직선
plt.scatter(X_test, sgdr.predict(X_test), color='gray') # 테스트 데이터의 예측 데이터
plt.scatter(X_test, y_test, color='green') # 테스트 데이터의 실제 데이터
plt.title('scor by hour') # 그래프 제목
plt.xlabel('hour') # x축 => 독립변수
plt.ylabel('score') # y축 => 종속변수
plt.show() # 그래픽 출력
